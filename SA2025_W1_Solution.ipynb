# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
df = pd.read_csv('Datasets/Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
df.set_index('name', inplace=True)
df.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin               model
# name
# chevrolet chevelle malibu          12.0          70    usa  chevrolet chevelle
# buick skylark 320                  11.5          70    usa       buick skylark
# plymouth satellite                 11.0          70    usa  plymouth satellite
# amc rebel sst                      12.0          70    usa           amc rebel
# ford torino                        10.5          70    usa         ford torino

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
df['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
df['hp_to_weight'] = df['horsepower'] / df['weight']

df.set_index('hp_to_weight', inplace=True)

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [raw]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
max_hp = df['horsepower'].max()

# Filter the row(s) with that horsepower
car_with_max_hp = df[df['horsepower'] == max_hp]

# Print the name(s) — now stored in the index
print("Car(s) with the highest horsepower:")
print(car_with_max_hp.index.tolist())
# Out:
# Car(s) with the highest horsepower:
# [116]

# %%
df.iloc[116]
# Out:
# mpg                           16.0
# cylinders                        8
# displacement                 400.0
# horsepower                   230.0
# weight                        4278
# acceleration                   9.5
# model_year                      73
# origin                         usa
# name            pontiac grand prix
# Name: 116, dtype: object

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
high_mpg_count = df[df['mpg'] >= 35].shape[0]
print("1. Cars with mpg ≥ 35:", high_mpg_count)
# Out:
# 1. Cars with mpg ≥ 35: 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
filtered = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
most_common_origin = filtered['origin'].mode()[0]
print("2. Most common origin (hp > 100 & weight < 3000):", most_common_origin)
# Out:
# 2. Most common origin (hp > 100 & weight < 3000): usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
mean_acc_japan = round(df[df['origin'] == 'japan']['acceleration'].mean(), 2)
print("3. Mean acceleration of Japanese cars:", mean_acc_japan)
# Out:
# 3. Mean acceleration of Japanese cars: 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
year_with_max_avg_mpg = df.groupby('model_year')['mpg'].mean().idxmax()
print("4. Year with highest average mpg:", year_with_max_avg_mpg)
# Out:
# 4. Year with highest average mpg: 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
median_mpg = df['mpg'].median()
filtered_df = df[df['mpg'] > median_mpg].copy()
filtered_df['hp_to_weight'] = filtered_df['horsepower'] / filtered_df['weight']
max_ratio = filtered_df['hp_to_weight'].max()
best_ratio_cars = filtered_df[filtered_df['hp_to_weight'] == max_ratio]
print("1. Car(s) with best HP-to-weight ratio (above-median mpg):")
print(best_ratio_cars[['name', 'horsepower', 'weight', 'hp_to_weight']])
# Out:
# 1. Car(s) with best HP-to-weight ratio (above-median mpg):
#         name  horsepower  weight  hp_to_weight
# 23  bmw 2002       113.0    2234      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
avg_mpg_by_year_origin = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(10,6))
sns.lineplot(data=avg_mpg_by_year_origin, x='model_year', y='mpg', hue='origin', marker='o')
plt.title("Evolution of Average MPG Over Years by Origin")
plt.xlabel("Model Year")
plt.ylabel("Average MPG")
plt.grid(True)
plt.legend(title="Origin")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    sizes=(20, 200),
    hue_order=['japan', 'europe', 'usa'],
    alpha=0.7
)
plt.title("Horsepower vs Weight of Cars\n(Size = MPG, Color = Origin)")
plt.xlabel("Horsepower")
plt.ylabel("Weight")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
df['model'] = df['name'].apply(lambda x: ' '.join(x.split()[:2]))

grouped = df.groupby('model')

consistent_models = grouped.filter(lambda x: x['model_year'].nunique() > 1)
model_stats = consistent_models.groupby('model').agg(
    appearances=('mpg', 'count'),
    std_mpg=('mpg', 'std'),
    avg_mpg=('mpg', 'mean')
).reset_index()

consistent_result = model_stats[(model_stats['std_mpg'] < 1.0) & (model_stats['appearances'] >= 2)]

consistent_result_sorted = consistent_result.sort_values(by=['appearances', 'avg_mpg'], ascending=[False, False])
print("4. Consistent car models (low mpg variation across years):")
print(consistent_result_sorted)
# Out:
# 4. Consistent car models (low mpg variation across years):
#               model  appearances   std_mpg    avg_mpg
# 28      dodge aspen            4  0.895824  19.575000
# 36     ford galaxie            3  0.577350  14.333333
# 21       datsun 310            2  0.565685  37.600000
# 46        mazda 626            2  0.212132  31.450000
# 26     datsun pl510            2  0.000000  27.000000
# 32         fiat 124            2  0.000000  26.000000
# 66        saab 99le            2  0.707107  24.500000
# 51   mercury zephyr            2  0.707107  20.300000
# 72      toyota mark            2  0.707107  19.500000
# 64    pontiac grand            2  0.000000  16.000000
# 49  mercury marquis            2  0.707107  11.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
